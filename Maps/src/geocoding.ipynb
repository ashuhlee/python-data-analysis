# %% [markdown]
# # Lab: Geocoding Analysis

# %%
import otter
grader = otter.Notebook("geocoding.ipynb")

# %% [markdown]
# # B. Questions
# ### **Question 1:** Complete the following code to obtain the coordinates of the Royal Ontario Museum in Canada.
#  - Follow the instructions in the comments.
#  - Select only one matching location to the search criteria.

# %%
#Remove the ellipsis (...) below and type your code. 

# import the Nominatim geocoder from geopy
...

# Create a Nominatim object in the variable geolocator.  
geolocator = ...

#Geocode the location "Royal Ontario Museum, Canada"
location = ... 

# Assign the values address, latitude, and longitude in the corresponding variables below. 
address = ...
latitude = ...
longitude = ... 

# END SOLUTION

# %%
grader.check("q1")

# %% [markdown]
# #### **Question 2:** How can you describe the location geocoded in Question 1?
# - Use the attributes 'type', 'class', and 'address type' to answer this question.
# - Respond to the question in a comment

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %%
grader.check("q2")

# %% [markdown]
# #### **Question 3:**  Geocode all possible locations that match the criteria "Niagara Falls".
# - For each location, print the name, address, latitude, longitude, and importance.
# - Add the addresses in a list  `locations`

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %%
grader.check("q3")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# #### **Question 4:** What is the location with the highest importance score?
# Answer in a comment by looking at the results in Question 3.

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# #### **Question 5:**  Complete the code below to create a base map pointing at the city of London, Ontario.
# Follow the comments.

# %%
#Remove the ellipsis (...) below and type your code. 
#Remove the ellipsis (...) below and type your code. 
# BEGIN SOLUTION

#Import the folium library. 
...

#Trust this notebook file
# !jupyter trust lab11_notebook.ipynb

#Get the coordinates
London_coordinates = ...

#Creating a base map with a focus on London, Ontario
london_map = ...

#Show your map in the cell output. 
...

# END SOLUTION

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 6:** Geocode three places around the city of London. You can choose your favourite restaurant, any place at the University that you prefer to study, your favourite shopping center, etc.
# - For each place store the name, latitude and longitude.
# - For storing the values, you can use variables. It is not required to use pandas here. It is up to you.

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 7:** Add markers for the three places in the map created in Question 5. Show the map.

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 8:** Save the map created in Question 7. Add any name of your preference.

# %%
#Remove the ellipsis (...) below and type your code. 
...

# %%
grader.check_all()
